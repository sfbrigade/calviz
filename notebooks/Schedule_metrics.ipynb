# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/parsed_data/schedules/all_schedules_cleaned.csv')

# %%
df
# Out:
#         km                            station                  train_id  time  \
# 0       78                           SAN JOSE     IC (HSR) 701_single_1   348
# 1      126                     GILROY (HSR) $     IC (HSR) 701_single_1   373
# 2        0  SALESFORCE TRANSIT CENTER (STC) $          HSR 801_single_2   310
# 3       24                           MILLBRAE          HSR 801_single_2   330
# 4       78                           SAN JOSE          HSR 801_single_2   365
# 5      126                     GILROY (HSR) $          HSR 801_single_2   391
# 6        0  SALESFORCE TRANSIT CENTER (STC) $    REG (C-EXP) nan_pair_0   313
# 7        2          TOWNSEND / 4TH AND KING $    REG (C-EXP) nan_pair_0   318
# 8       11                           BAYSHORE    REG (C-EXP) nan_pair_0   329
# 9       24                           MILLBRAE    REG (C-EXP) nan_pair_0   338
# 10      27                           BROADWAY    REG (C-EXP) nan_pair_0   341
# 11      33                       HAYWARD PARK    REG (C-EXP) nan_pair_0   345
# 12      35                          HILLSDALE    REG (C-EXP) nan_pair_0   348
# 13      40                         SAN CARLOS    REG (C-EXP) nan_pair_0   352
# 14      43                       REDWOOD CITY    REG (C-EXP) nan_pair_0   356
# 15      51                          PALO ALTO    REG (C-EXP) nan_pair_0   361
# 16      57                        SAN ANTONIO    REG (C-EXP) nan_pair_0   365
# 17      60                      MOUNTAIN VIEW    REG (C-EXP) nan_pair_0   369
# 18      65                          SUNNYVALE    REG (C-EXP) nan_pair_0   373
# 19      68                           LAWRENCE    REG (C-EXP) nan_pair_0   376
# 20       0  SALESFORCE TRANSIT CENTER (STC) $          HSR 901_single_3   316
# 21       2          TOWNSEND / 4TH AND KING $          HSR 901_single_3   321
# 22      78                           SAN JOSE          HSR 901_single_3   372
# 23     126                     GILROY (HSR) $          HSR 901_single_3   397
# 24      78                           SAN JOSE     IC (HSR) 751_single_4   384
# 25     126                     GILROY (HSR) $     IC (HSR) 751_single_4   409
# 26      78                           SAN JOSE    REG (C-EXP) nan_pair_0   386
# 27      81                     TAMIEN (HSR) $    REG (C-EXP) nan_pair_0   389
# 28       0  SALESFORCE TRANSIT CENTER (STC) $  REG (C-EXP) 503_single_5   321
# 29       2          TOWNSEND / 4TH AND KING $  REG (C-EXP) 503_single_5   326
# ...    ...                                ...                       ...   ...
# 15898   16                MORGAN HILL (HSR) $  REG (C-EXP) nan_pair_123  1431
# 15899   35               BLOSSOM HILL (HSR) $  REG (C-EXP) nan_pair_123  1440
# 15900   40                    CAPITOL (HSR) $  REG (C-EXP) nan_pair_123  1444
# 15901   45                     TAMIEN (HSR) $  REG (C-EXP) nan_pair_123  1448
# 15902   48                           SAN JOSE  REG (C-EXP) nan_pair_123  1451
# 15903    0                     GILROY (HSR) $        HSR nan_single_170  1430
# 15904   48                           SAN JOSE        HSR nan_single_170  1453
# 15905  101                           MILLBRAE        HSR nan_single_170  1485
# 15906  126  SALESFORCE TRANSIT CENTER (STC) $        HSR nan_single_170  1505
# 15907    0                     GILROY (HSR) $        HSR nan_single_171  1434
# 15908   48                           SAN JOSE        HSR nan_single_171  1457
# 15909   61                          SUNNYVALE  REG (C-EXP) nan_pair_123  1468
# 15910   65                      MOUNTAIN VIEW  REG (C-EXP) nan_pair_123  1472
# 15911   75                          PALO ALTO  REG (C-EXP) nan_pair_123  1478
# 15912   83                       REDWOOD CITY  REG (C-EXP) nan_pair_123  1483
# 15913   91                          HILLSDALE  REG (C-EXP) nan_pair_123  1489
# 15914  101                           MILLBRAE  REG (C-EXP) nan_pair_123  1496
# 15915  109               SOUTH SAN FRANCISCO   REG (C-EXP) nan_pair_123  1501
# 15916  121                        22nd STREET  REG (C-EXP) nan_pair_123  1509
# 15917  124          TOWNSEND / 4TH AND KING $  REG (C-EXP) nan_pair_123  1513
# 15918  126  SALESFORCE TRANSIT CENTER (STC) $  REG (C-EXP) nan_pair_123  1517
# 15919    0                     GILROY (HSR) $         HSR 38_single_172  1445
# 15920   48                           SAN JOSE         HSR 38_single_172  1468
# 15921  101                           MILLBRAE         HSR 38_single_172  1500
# 15922  124          TOWNSEND / 4TH AND KING $         HSR 38_single_172  1516
# 15923  126  SALESFORCE TRANSIT CENTER (STC) $         HSR 38_single_172  1520
# 15924    0                     GILROY (HSR) $        HSR nan_single_173  1449
# 15925   48                           SAN JOSE        HSR nan_single_173  1472
# 15926    0                     GILROY (HSR) $        HSR nan_single_174  1464
# 15927   48                           SAN JOSE        HSR nan_single_174  1487
#
#        hr  min     scenario
# 0       5   48  Baseline SB
# 1       6   13  Baseline SB
# 2       5   10  Baseline SB
# 3       5   30  Baseline SB
# 4       6    5  Baseline SB
# 5       6   31  Baseline SB
# 6       5   13  Baseline SB
# 7       5   18  Baseline SB
# 8       5   29  Baseline SB
# 9       5   38  Baseline SB
# 10      5   41  Baseline SB
# 11      5   45  Baseline SB
# 12      5   48  Baseline SB
# 13      5   52  Baseline SB
# 14      5   56  Baseline SB
# 15      6    1  Baseline SB
# 16      6    5  Baseline SB
# 17      6    9  Baseline SB
# 18      6   13  Baseline SB
# 19      6   16  Baseline SB
# 20      5   16  Baseline SB
# 21      5   21  Baseline SB
# 22      6   12  Baseline SB
# 23      6   37  Baseline SB
# 24      6   24  Baseline SB
# 25      6   49  Baseline SB
# 26      6   26  Baseline SB
# 27      6   29  Baseline SB
# 28      5   21  Baseline SB
# 29      5   26  Baseline SB
# ...    ..  ...          ...
# 15898  23   51      HIgh NB
# 15899  24    0      HIgh NB
# 15900  24    4      HIgh NB
# 15901  24    8      HIgh NB
# 15902  24   11      HIgh NB
# 15903  23   50      HIgh NB
# 15904  24   13      HIgh NB
# 15905  24   45      HIgh NB
# 15906  25    5      HIgh NB
# 15907  23   54      HIgh NB
# 15908  24   17      HIgh NB
# 15909  24   28      HIgh NB
# 15910  24   32      HIgh NB
# 15911  24   38      HIgh NB
# 15912  24   43      HIgh NB
# 15913  24   49      HIgh NB
# 15914  24   56      HIgh NB
# 15915  25    1      HIgh NB
# 15916  25    9      HIgh NB
# 15917  25   13      HIgh NB
# 15918  25   17      HIgh NB
# 15919  24    5      HIgh NB
# 15920  24   28      HIgh NB
# 15921  25    0      HIgh NB
# 15922  25   16      HIgh NB
# 15923  25   20      HIgh NB
# 15924  24    9      HIgh NB
# 15925  24   32      HIgh NB
# 15926  24   24      HIgh NB
# 15927  24   47      HIgh NB
#
# [15928 rows x 7 columns]

# %%
def stops_to_durations(df):
    #Get departure and arrival stop info
    df_stops_arr = df.copy()
    df = df.rename(columns={"station": "departure_station",
                                        "time": "departure_time",
                                        "hr": "departure_hour",
                                        "min": "departure_minute",
                                        "km": "departure_km"})
    
    df_stops_arr = df_stops_arr.rename(columns={"station": "arrival_station",
                                        "time": "arrival_time",
                                        "hr": "arrival_hour",
                                        "min": "arrival_minute",
                                        "km": "arrival_km"})

    #Join the two on train ID and scenario
    df = df.merge(df_stops_arr, on=['scenario', 'train_id'])

    #Thow out any journeys that do not go forwards in time
    df = df[df['arrival_time'] > df['departure_time']]

    #Add trip duration column
    df['trip_duration'] = df['arrival_time'] - df['departure_time']

    return df
stops_to_durations(df)
# Out:
#        km                  departure_station                  train_id  \
# 10325   0  SALESFORCE TRANSIT CENTER (STC) $   REG (C-EXP) nan_pair_44
# 10329   2          TOWNSEND / 4TH AND KING $   REG (C-EXP) nan_pair_44
# 10333   5                        22nd STREET   REG (C-EXP) nan_pair_44
# 10337  17               SOUTH SAN FRANCISCO    REG (C-EXP) nan_pair_44
# 10341  24                           MILLBRAE   REG (C-EXP) nan_pair_44
# 10345  35                          HILLSDALE   REG (C-EXP) nan_pair_44
# 10349  43                       REDWOOD CITY   REG (C-EXP) nan_pair_44
# 10353  51                          PALO ALTO   REG (C-EXP) nan_pair_44
# 10357  60                      MOUNTAIN VIEW   REG (C-EXP) nan_pair_44
# 10361  65                          SUNNYVALE   REG (C-EXP) nan_pair_44
# 10473   0  SALESFORCE TRANSIT CENTER (STC) $   REG (C-EXP) nan_pair_49
# 10477   2          TOWNSEND / 4TH AND KING $   REG (C-EXP) nan_pair_49
# 10481   5                        22nd STREET   REG (C-EXP) nan_pair_49
# 10485  17               SOUTH SAN FRANCISCO    REG (C-EXP) nan_pair_49
# 10489  24                           MILLBRAE   REG (C-EXP) nan_pair_49
# 10493  35                          HILLSDALE   REG (C-EXP) nan_pair_49
# 10497  43                       REDWOOD CITY   REG (C-EXP) nan_pair_49
# 10501  51                          PALO ALTO   REG (C-EXP) nan_pair_49
# 10505  60                      MOUNTAIN VIEW   REG (C-EXP) nan_pair_49
# 10509  65                          SUNNYVALE   REG (C-EXP) nan_pair_49
# 10621   0  SALESFORCE TRANSIT CENTER (STC) $   REG (C-EXP) nan_pair_54
# 10625   2          TOWNSEND / 4TH AND KING $   REG (C-EXP) nan_pair_54
# 10629   5                        22nd STREET   REG (C-EXP) nan_pair_54
# 10633  17               SOUTH SAN FRANCISCO    REG (C-EXP) nan_pair_54
# 10637  24                           MILLBRAE   REG (C-EXP) nan_pair_54
# 10641  35                          HILLSDALE   REG (C-EXP) nan_pair_54
# 10645  43                       REDWOOD CITY   REG (C-EXP) nan_pair_54
# 10649  51                          PALO ALTO   REG (C-EXP) nan_pair_54
# 10653  60                      MOUNTAIN VIEW   REG (C-EXP) nan_pair_54
# 10657  65                          SUNNYVALE   REG (C-EXP) nan_pair_54
# ...    ..                                ...                       ...
# 12185   0  SALESFORCE TRANSIT CENTER (STC) $  REG (C-EXP) nan_pair_109
# 12189   2          TOWNSEND / 4TH AND KING $  REG (C-EXP) nan_pair_109
# 12193   5                        22nd STREET  REG (C-EXP) nan_pair_109
# 12197  17               SOUTH SAN FRANCISCO   REG (C-EXP) nan_pair_109
# 12201  24                           MILLBRAE  REG (C-EXP) nan_pair_109
# 12205  35                          HILLSDALE  REG (C-EXP) nan_pair_109
# 12209  43                       REDWOOD CITY  REG (C-EXP) nan_pair_109
# 12213  51                          PALO ALTO  REG (C-EXP) nan_pair_109
# 12217  60                      MOUNTAIN VIEW  REG (C-EXP) nan_pair_109
# 12221  65                          SUNNYVALE  REG (C-EXP) nan_pair_109
# 12333   0  SALESFORCE TRANSIT CENTER (STC) $  REG (C-EXP) nan_pair_114
# 12337   2          TOWNSEND / 4TH AND KING $  REG (C-EXP) nan_pair_114
# 12341   5                        22nd STREET  REG (C-EXP) nan_pair_114
# 12345  17               SOUTH SAN FRANCISCO   REG (C-EXP) nan_pair_114
# 12349  24                           MILLBRAE  REG (C-EXP) nan_pair_114
# 12353  35                          HILLSDALE  REG (C-EXP) nan_pair_114
# 12357  43                       REDWOOD CITY  REG (C-EXP) nan_pair_114
# 12361  51                          PALO ALTO  REG (C-EXP) nan_pair_114
# 12365  60                      MOUNTAIN VIEW  REG (C-EXP) nan_pair_114
# 12369  65                          SUNNYVALE  REG (C-EXP) nan_pair_114
# 12481   0  SALESFORCE TRANSIT CENTER (STC) $  REG (C-EXP) nan_pair_119
# 12485   2          TOWNSEND / 4TH AND KING $  REG (C-EXP) nan_pair_119
# 12489   5                        22nd STREET  REG (C-EXP) nan_pair_119
# 12493  17               SOUTH SAN FRANCISCO   REG (C-EXP) nan_pair_119
# 12497  24                           MILLBRAE  REG (C-EXP) nan_pair_119
# 12501  35                          HILLSDALE  REG (C-EXP) nan_pair_119
# 12505  43                       REDWOOD CITY  REG (C-EXP) nan_pair_119
# 12509  51                          PALO ALTO  REG (C-EXP) nan_pair_119
# 12513  60                      MOUNTAIN VIEW  REG (C-EXP) nan_pair_119
# 12517  65                          SUNNYVALE  REG (C-EXP) nan_pair_119
#
#        departure_time  departure_hour  departure_minute scenario  \
# 10325             658              10                58  High SB
# 10329             663              11                 3  High SB
# 10333             667              11                 7  High SB
# 10337             675              11                15  High SB
# 10341             680              11                20  High SB
# 10345             687              11                27  High SB
# 10349             693              11                33  High SB
# 10353             698              11                38  High SB
# 10357             704              11                44  High SB
# 10361             708              11                48  High SB
# 10473             718              11                58  High SB
# 10477             723              12                 3  High SB
# 10481             727              12                 7  High SB
# 10485             735              12                15  High SB
# 10489             740              12                20  High SB
# 10493             747              12                27  High SB
# 10497             753              12                33  High SB
# 10501             758              12                38  High SB
# 10505             764              12                44  High SB
# 10509             768              12                48  High SB
# 10621             778              12                58  High SB
# 10625             783              13                 3  High SB
# 10629             787              13                 7  High SB
# 10633             795              13                15  High SB
# 10637             800              13                20  High SB
# 10641             807              13                27  High SB
# 10645             813              13                33  High SB
# 10649             818              13                38  High SB
# 10653             824              13                44  High SB
# 10657             828              13                48  High SB
# ...               ...             ...               ...      ...
# 12185            1258              20                58  High SB
# 12189            1263              21                 3  High SB
# 12193            1267              21                 7  High SB
# 12197            1275              21                15  High SB
# 12201            1280              21                20  High SB
# 12205            1287              21                27  High SB
# 12209            1293              21                33  High SB
# 12213            1298              21                38  High SB
# 12217            1304              21                44  High SB
# 12221            1308              21                48  High SB
# 12333            1318              21                58  High SB
# 12337            1323              22                 3  High SB
# 12341            1327              22                 7  High SB
# 12345            1335              22                15  High SB
# 12349            1340              22                20  High SB
# 12353            1347              22                27  High SB
# 12357            1353              22                33  High SB
# 12361            1358              22                38  High SB
# 12365            1364              22                44  High SB
# 12369            1368              22                48  High SB
# 12481            1378              22                58  High SB
# 12485            1383              23                 3  High SB
# 12489            1387              23                 7  High SB
# 12493            1395              23                15  High SB
# 12497            1400              23                20  High SB
# 12501            1407              23                27  High SB
# 12505            1413              23                33  High SB
# 12509            1418              23                38  High SB
# 12513            1424              23                44  High SB
# 12517            1428              23                48  High SB
#
#                          arrival_station  arrival_time  arrival_hour  \
# 10325  SALESFORCE TRANSIT CENTER (STC) $           673            11
# 10329          TOWNSEND / 4TH AND KING $           678            11
# 10333                        22nd STREET           682            11
# 10337               SOUTH SAN FRANCISCO            690            11
# 10341                           MILLBRAE           695            11
# 10345                          HILLSDALE           702            11
# 10349                       REDWOOD CITY           708            11
# 10353                          PALO ALTO           713            11
# 10357                      MOUNTAIN VIEW           719            11
# 10361                          SUNNYVALE           723            12
# 10473  SALESFORCE TRANSIT CENTER (STC) $           733            12
# 10477          TOWNSEND / 4TH AND KING $           738            12
# 10481                        22nd STREET           742            12
# 10485               SOUTH SAN FRANCISCO            750            12
# 10489                           MILLBRAE           755            12
# 10493                          HILLSDALE           762            12
# 10497                       REDWOOD CITY           768            12
# 10501                          PALO ALTO           773            12
# 10505                      MOUNTAIN VIEW           779            12
# 10509                          SUNNYVALE           783            13
# 10621  SALESFORCE TRANSIT CENTER (STC) $           793            13
# 10625          TOWNSEND / 4TH AND KING $           798            13
# 10629                        22nd STREET           802            13
# 10633               SOUTH SAN FRANCISCO            810            13
# 10637                           MILLBRAE           815            13
# 10641                          HILLSDALE           822            13
# 10645                       REDWOOD CITY           828            13
# 10649                          PALO ALTO           833            13
# 10653                      MOUNTAIN VIEW           839            13
# 10657                          SUNNYVALE           843            14
# ...                                  ...           ...           ...
# 12185  SALESFORCE TRANSIT CENTER (STC) $          1273            21
# 12189          TOWNSEND / 4TH AND KING $          1278            21
# 12193                        22nd STREET          1282            21
# 12197               SOUTH SAN FRANCISCO           1290            21
# 12201                           MILLBRAE          1295            21
# 12205                          HILLSDALE          1302            21
# 12209                       REDWOOD CITY          1308            21
# 12213                          PALO ALTO          1313            21
# 12217                      MOUNTAIN VIEW          1319            21
# 12221                          SUNNYVALE          1323            22
# 12333  SALESFORCE TRANSIT CENTER (STC) $          1333            22
# 12337          TOWNSEND / 4TH AND KING $          1338            22
# 12341                        22nd STREET          1342            22
# 12345               SOUTH SAN FRANCISCO           1350            22
# 12349                           MILLBRAE          1355            22
# 12353                          HILLSDALE          1362            22
# 12357                       REDWOOD CITY          1368            22
# 12361                          PALO ALTO          1373            22
# 12365                      MOUNTAIN VIEW          1379            22
# 12369                          SUNNYVALE          1383            23
# 12481  SALESFORCE TRANSIT CENTER (STC) $          1393            23
# 12485          TOWNSEND / 4TH AND KING $          1398            23
# 12489                        22nd STREET          1402            23
# 12493               SOUTH SAN FRANCISCO           1410            23
# 12497                           MILLBRAE          1415            23
# 12501                          HILLSDALE          1422            23
# 12505                       REDWOOD CITY          1428            23
# 12509                          PALO ALTO          1433            23
# 12513                      MOUNTAIN VIEW          1439            23
# 12517                          SUNNYVALE          1443            24
#
#        arrival_minute  trip_duration
# 10325              13             15
# 10329              18             15
# 10333              22             15
# 10337              30             15
# 10341              35             15
# 10345              42             15
# 10349              48             15
# 10353              53             15
# 10357              59             15
# 10361               3             15
# 10473              13             15
# 10477              18             15
# 10481              22             15
# 10485              30             15
# 10489              35             15
# 10493              42             15
# 10497              48             15
# 10501              53             15
# 10505              59             15
# 10509               3             15
# 10621              13             15
# 10625              18             15
# 10629              22             15
# 10633              30             15
# 10637              35             15
# 10641              42             15
# 10645              48             15
# 10649              53             15
# 10653              59             15
# 10657               3             15
# ...               ...            ...
# 12185              13             15
# 12189              18             15
# 12193              22             15
# 12197              30             15
# 12201              35             15
# 12205              42             15
# 12209              48             15
# 12213              53             15
# 12217              59             15
# 12221               3             15
# 12333              13             15
# 12337              18             15
# 12341              22             15
# 12345              30             15
# 12349              35             15
# 12353              42             15
# 12357              48             15
# 12361              53             15
# 12365              59             15
# 12369               3             15
# 12481              13             15
# 12485              18             15
# 12489              22             15
# 12493              30             15
# 12497              35             15
# 12501              42             15
# 12505              48             15
# 12509              53             15
# 12513              59             15
# 12517               3             15
#
# [70 rows x 12 columns]

# %%
'''
Hour
origin_id
origin_name
dest_id
scenario
Min Wait at Origin Station
Average Wait at Origin Station
Max Wait at Origin Station
Min Length of Journey
Average Length of Journey
Max Length of Journey
CO2 Emissions
Ridership Number
'''
