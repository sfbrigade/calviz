# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("../data/1 - Weekday Schedule/Baseline NB-Table 1.csv")

# %%
new_cols = ["km", "From:"]

for item in zip(df.columns[2:], df.iloc[0][2:]):
    new_cols.append(str(item[0] + "_" + str(item[1])))

df.columns = new_cols

# %%
data = df.iloc[1:]

# %%
data.head()
# Out:
#      km                 From: REG (C-EXP)_310 REG (C-EXP).1_508  \
# 1   0.0        GILROY (HSR) $
# 2  10.0   SAN MARTIIN (HSR) $
# 3  16.0   MORGAN HILL (HSR) $
# 4  35.0  BLOSSOM HILL (HSR) $
# 5  40.0       CAPITOL (HSR) $
#
#   REG (C-EXP).2_nan REG (C-EXP).3_312  HSR_806 REG (C-EXP).4_312  \
# 1            5:03                       5:31
# 2           |                          |
# 3            5:13                      |
# 4           |                          |
# 5            5:27                      |
#
#   REG (C-EXP).5_510 REG (C-EXP).6_nan  ... HSR.55_nan REG (C-EXP).131_nan  \
# 1                              5:33    ...    22:55
# 2                             |        ...    |
# 3                             |        ...    |
# 4                              5:52    ...    |
# 5                              5:57    ...    |
#
#   REG (C-EXP).132_nan REG (C-EXP).133_nan IC (HSR).53_nan HSR.56_nan  \
# 1                                                 23:13      23:31
# ...

# %%
for col in data.columns[2:]:
    data[col] = pd.to_timedelta(data[col]+":00", errors="coerce")
# Out:
# /Users/jeremymiller/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data
# Out:
#        km                              From: REG (C-EXP)_310  \
# 1     0.0                     GILROY (HSR) $             NaT
# 2    10.0                SAN MARTIIN (HSR) $             NaT
# 3    16.0                MORGAN HILL (HSR) $             NaT
# 4    35.0               BLOSSOM HILL (HSR) $             NaT
# 5    40.0                    CAPITOL (HSR) $             NaT
# 6    45.0                     TAMIEN (HSR) $        05:19:00
# 7    48.0                           SAN JOSE        05:22:00
# 8     NaN                           SAN JOSE        05:24:00
# 9    50.0                       COLLEGE PARK             NaT
# 10   52.0                        SANTA CLARA             NaT
# 11   58.0                           LAWRENCE        05:38:00
# 12   61.0                          SUNNYVALE             NaT
# 13   65.0                      MOUNTAIN VIEW        05:43:00
# 14   69.0                        SAN ANTONIO             NaT
# ...

# %%
data.to_csv("../data/parsed_data/schedules/baseline_NB.csv", index=False)

# %%
data['REG (C-EXP)_310'].str.strip()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6     5:19
# 7     5:22
# 8     5:24
# 9        |
# 10       |
# 11    5:38
# 12       |
# 13    5:43
# 14       |
# 15       |
# 16    5:50
# 17       |
# 18    5:53
# 19    5:57
# 20       |
# 21       |
# 22    6:03
# 23       |
# 24    6:06
# 25    6:09
# 26       |
# 27    6:13
# 28       |
# 29    6:18
# 30       |
# 31    6:25
# 32    6:30
# 33    6:34
# Name: REG (C-EXP)_310, dtype: object
